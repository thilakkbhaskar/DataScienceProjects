# %%
import numpy as np  # useful for many scientific computing in Python
import pandas as pd # primary data structure library
#!conda install -c anaconda xlrd --yes

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#                             Very interested  Somewhat interested  \
# Topic
# Big Data (Spark / Hadoop)              1332                  729
# Data Analysis / Statistics             1688                  444
# Data Journalism                         429                 1081
# Data Visualization                     1340                  734
# Deep Learning                          1263                  770
#
#                             Not interested
# Topic
# Big Data (Spark / Hadoop)              127
# Data Analysis / Statistics              60
# Data Journalism                        610
# Data Visualization                     102
# Deep Learning                          136

# %%
#sorted_df=df_data_1.sort_values(by=['Very Interested'])
#df_data_1.sort_values(['Very Interested'], ascending=False, axis=0, inplace=True)
#df_data_1.sort_index(axis=1, inplace=True)
#sorted_df=df_data_1.sort_values(['Very Interested'])
#sorted_df=df_data_1.sort_values('Very Interested')
#sorted_df=sorted_df.reindex(columns=['Topic', 'Very interested', 'Somewhat interested', 'Not interested']).sort_index(axis=1)
df_data_1.head()
# Out:
#                             Very interested  Somewhat interested  \
# Topic
# Big Data (Spark / Hadoop)              1332                  729
# Data Analysis / Statistics             1688                  444
# Data Journalism                         429                 1081
# Data Visualization                     1340                  734
# Deep Learning                          1263                  770
#
#                             Not interested
# Topic
# Big Data (Spark / Hadoop)              127
# Data Analysis / Statistics              60
# Data Journalism                        610
# Data Visualization                     102
# Deep Learning                          136

# %%
df_data_1['Very interested']=df_data_1['Very interested']*100/2233
df_data_1['Somewhat interested']=df_data_1['Somewhat interested']*100/2233
df_data_1['Not interested']=df_data_1['Not interested']*100/2233
df_data_1.head()
# Out:
#                         Topic  Very interested  Somewhat interested  \
# 0   Big Data (Spark / Hadoop)        59.650694            32.646664
# 1  Data Analysis / Statistics        75.593372            19.883565
# 2             Data Journalism        19.211823            48.410210
# 3          Data Visualization        60.008957            32.870578
# 4               Deep Learning        56.560681            34.482759
#
#    Not interested
# 0        5.687416
# 1        2.686968
# 2       27.317510
# 3        4.567846
# 4        6.090461

# %%
df_data_1.head()
# Out:
#                             Very interested  Somewhat interested  \
# Topic
# Big Data (Spark / Hadoop)              1332                  729
# Data Analysis / Statistics             1688                  444
# Data Journalism                         429                 1081
# Data Visualization                     1340                  734
# Deep Learning                          1263                  770
#
#                             Not interested
# Topic
# Big Data (Spark / Hadoop)              127
# Data Analysis / Statistics              60
# Data Journalism                        610
# Data Visualization                     102
# Deep Learning                          136

# %%
# use the inline backend to generate the plots within the browser
# %matplotlib inline 

import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.style.use('ggplot') # optional: for ggplot-like style

# check for latest version of Matplotlib
print ('Matplotlib version: ', mpl.__version__) # >= 2.0.0
# Out:
# Matplotlib version:  3.0.2

# %%
df_data_1.plot(kind='bar', figsize=(20, 8), color='steelblue')
plt.xlabel('TOPICS')
plt.title('Percentage of respondents interest in Data science areas')

# annotate value labels to each country
for index, value in enumerate(df_data_1['Very interested']): 
    label = format(int(value), ',') # format int with commas
    
    # place text at the end of bar (subtracting 47000 from x, and 0.1 from y to make it fit within the bar)
    plt.annotate(label, xy=(value, index - 0.10), color='white')



plt.show()

# %%
df_data_1.index = df_data_1.index.map(int) # let's change the index values of df_top5 to type integer for plotting
df_data_1.plot(kind='bar', 
             stacked=False,
             figsize=(20, 10),# pass a tuple (x, y) size
             color=['#5cb85c', '#5bc0de', '#d9534f']
              )
#use color #5cb85c for the Very interested bars, color #5bc0de for the Somewhat interested bars, and color #d9534f for the Not interested bars,
plt.title('Percentage of respondents interest in Data science areas')
plt.ylabel('% Interest')
plt.xlabel('TOPIC')

plt.show()

# %%
body = client_c4998831b9044e75a0100126bd9fdef3.get_object(Bucket='datavisualizationusingpython-donotdelete-pr-tdlmohroqp4xqm',Key='Police_Department_Incidents_-_Previous_Year__2016_.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_incidents = pd.read_csv(body)
df_incidents.head()
# Out:
#    IncidntNum      Category                                        Descript  \
# 0   120058272   WEAPON LAWS                       POSS OF PROHIBITED WEAPON
# 1   120058272   WEAPON LAWS  FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE
# 2   141059263      WARRANTS                                  WARRANT ARREST
# 3   160013662  NON-CRIMINAL                                   LOST PROPERTY
# 4   160002740  NON-CRIMINAL                                   LOST PROPERTY
#
#   DayOfWeek                    Date   Time  PdDistrict      Resolution  \
# 0    Friday  01/29/2016 12:00:00 AM  11:00    SOUTHERN  ARREST, BOOKED
# 1    Friday  01/29/2016 12:00:00 AM  11:00    SOUTHERN  ARREST, BOOKED
# 2    Monday  04/25/2016 12:00:00 AM  14:59     BAYVIEW  ARREST, BOOKED
# 3   Tuesday  01/05/2016 12:00:00 AM  23:50  TENDERLOIN            NONE
# 4    Friday  01/01/2016 12:00:00 AM  00:30     MISSION            NONE
#
#                   Address           X          Y  \
# ...

# %%
df_data_2.rename(columns={'PdDistrict':'Neighborhood'}, inplace=True)
df_data_2.rename(columns={'Address':'Count'}, inplace=True)
df_Crime_data=df_data_2.groupby('Neighborhood').count()
df_Crime_data.rename(columns={'Neighborhood':'Count'}, inplace=True)
df_Crime_count=df_Crime_data['Count'].to_frame()
df_Crime_count
# Out:
#               Count
# Neighborhood
# BAYVIEW       14303
# CENTRAL       17666
# INGLESIDE     11594
# MISSION       19503
# NORTHERN      20100
# PARK           8699
# RICHMOND       8922
# SOUTHERN      28445
# TARAVAL       11325
# TENDERLOIN     9942

# %%
# !conda install -c conda-forge folium=0.5.0 --yes
import folium

print('Folium installed and imported!')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     altair-3.2.0               |           py36_0         770 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     certifi-2019.9.11          |           py36_0         147 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     ca-certificates-2019.9.11  |       hecc5488_0         144 KB  conda-forge
#     openssl-1.1.1c             |       h516909a_0         2.1 MB  conda-forge
#     ------------------------------------------------------------
# ...

# %%
df_incidents.head()
# Out:
#    IncidntNum      Category                                        Descript  \
# 0   120058272   WEAPON LAWS                       POSS OF PROHIBITED WEAPON
# 1   120058272   WEAPON LAWS  FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE
# 2   141059263      WARRANTS                                  WARRANT ARREST
# 3   160013662  NON-CRIMINAL                                   LOST PROPERTY
# 4   160002740  NON-CRIMINAL                                   LOST PROPERTY
#
#   DayOfWeek                    Date   Time  PdDistrict      Resolution  \
# 0    Friday  01/29/2016 12:00:00 AM  11:00    SOUTHERN  ARREST, BOOKED
# 1    Friday  01/29/2016 12:00:00 AM  11:00    SOUTHERN  ARREST, BOOKED
# 2    Monday  04/25/2016 12:00:00 AM  14:59     BAYVIEW  ARREST, BOOKED
# 3   Tuesday  01/05/2016 12:00:00 AM  23:50  TENDERLOIN            NONE
# 4    Friday  01/01/2016 12:00:00 AM  00:30     MISSION            NONE
#
#                   Address           X          Y  \
# ...

# %%
# !conda install -c anaconda xlrd --yes
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - xlrd
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2019.6.16          |           py36_1         156 KB  anaconda
#     ca-certificates-2019.5.15  |                1         134 KB  anaconda
#     xlrd-1.2.0                 |           py36_0         188 KB  anaconda
#     openssl-1.1.1              |       h7b6447c_0         5.0 MB  anaconda
#     ------------------------------------------------------------
#                                            Total:         5.5 MB
#
# The following packages will be UPDATED:
#
#     openssl:         1.1.1c-h516909a_0    conda-forge --> 1.1.1-h7b6447c_0 anaconda
#     xlrd:            1.2.0-py36_0                     --> 1.2.0-py36_0     anaconda
#
# ...

# %%
#https://cocl.us/sanfran_geojson.
    # download countries geojson file
# !wget --quiet https://cocl.us/sanfran_geojson -O sanfran_geoj.json
    
print('GeoJSON file downloaded!')

sfo_geo = r'sanfran_geoj.json' # geojson file
# Out:
# GeoJSON file downloaded!

# %%
# create a plain world map
#world_map = folium.Map(location=[0, 0], zoom_start=2, tiles='Mapbox Bright')

# %%
# San Francisco latitude and longitude values
latitude = 37.77
longitude = -122.42
# create map and display it
sanfran_map = folium.Map(location=[latitude, longitude], zoom_start=12)

# display the map of San Francisco
sanfran_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# get the first 100 crimes in the df_incidents dataframe
limit = 100
df_incidents = df_incidents.iloc[0:limit, :]

# %%
# generate choropleth map using the total immigration of each country to Canada from 1980 to 2013
sanfran_map.choropleth(
    geo_data=sfo_geo,
    data=df_incidents,
    key_on='feature.properties.name',
    fill_color='YlOrRd', 
    fill_opacity=0.7, 
    line_opacity=0.2,
    legend_name='SFO crime scene',
    reset=True
)

# display map
sanfran_map
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-111-46b7c3fab4e5> in <module>
#       8     line_opacity=0.2,
#       9     legend_name='SFO crime scene',
# ---> 10     reset=True
#      11 )
#      12
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/folium/folium.py in choropleth(self, geo_data, data, columns, key_on, threshold_scale, fill_color, fill_opacity, line_color, line_weight, line_opacity, name, legend_name, topojson, reset, smooth_factor, highlight)
#     250         if hasattr(data, 'set_index'):
#     251             # This is a pd.DataFrame
# --> 252             color_data = data.set_index(columns[0])[columns[1]].to_dict()
#     253         elif hasattr(data, 'to_dict'):
#     254             # This is a pd.Series
#
# TypeError: 'NoneType' object is not subscriptable
